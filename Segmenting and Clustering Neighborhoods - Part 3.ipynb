# %% [markdown]
# # Download Toronto Neighboorhood Information from Wikipedia and format it accordingly

# %% [markdown]
# ### Installing, importing necessary packages

# %%
# Install as necessary
### pip install arcgis
from arcgis.gis import GIS
from arcgis.geocoding import get_geocoders, batch_geocode

# Import packages
import pandas as pd
import numpy as np

import requests # library to handle requests

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import folium # map rendering library

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
# Out:
# C:\Users\marky\anaconda3\lib\site-packages\arcgis\features\_data\geodataset\utils.py:15: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   pd.datetime,

# %% [markdown]
# ### Import data from wikipedia and drop rows from dataframe where 'borough' is equal to 'Not assigned'

# %%
# Wikipedia file URL
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# Using pandas to load data from wikidpedia page
df_CA=pd.read_html(url,header=0)[0]
df_CA.replace('Not assigned',np.NaN,inplace=True)
df_CA.dropna(subset=['Borough'],inplace=True)

# %% [markdown]
# ### Find coordinates for postal codes and add onto current dataset
# #### Using arcgis geocoder for a batch pull of coordinates

# %%
# Getting postal codes from dataframe and storing into a list
postal_codes=df_CA["Postal code"].tolist()

# %%
# Set geocode setting for arcgis - sensitive info 
# withheld (i.e., username and password)
gis = GIS("http://www.arcgis.com", "User_Name", "Pass_Word")

## use the first of GIS's configured geocoders
geocoder=get_geocoders(gis)[0]
CA_geo=batch_geocode(postal_codes,source_country="CA")

# %% [markdown]
# ### Use for loop to goes postal codes and coordinates - then stores it into a dataframe

# %%
## For loop to collect coordinates
Postal_code=[]
Lat=[]
Long=[]
for i in range(len(CA_geo)):
    Postal_code.append(CA_geo[i]['address'])
    Lat.append(CA_geo[i]['location']['y'])
    Long.append(CA_geo[i]['location']['x'])

# Convert collected data into a dataframe
df_Postal_code=pd.DataFrame(Postal_code,columns=['Postal code'])
df_Lat=pd.DataFrame(Lat,columns=['Latitude'])
df_Long=pd.DataFrame(Long,columns=['Longitude'])

# Merge tables to include postal codes and their corrsponding coordinates
df_CA_coords=pd.merge(df_Lat,df_Long,left_index=True,right_index=True)
df_CA_coords_code=pd.merge(df_Postal_code,df_CA_coords,left_index=True,right_index=True)

# Merge tables to include postal codes, boroughs, neighborhoods & coordinates (longitude & Latitude)
df_CA_geo=pd.merge(df_CA,df_CA_coords_code)

# Stored as CSV to save lookup credits during the code building process
df_CA_geo.to_csv('df_CA_geo.csv', sep='\t', encoding='utf-8')

# %%
# Read from saved csv file and store into dataframe
df_CA_geo=pd.read_csv('df_CA_geo.csv', sep='\t')
df_CA_geo.drop('Unnamed: 0', axis=1,inplace=True)

# %% [markdown]
# ### Map neighborhoods by Toronto onto map and cluster boroughs

# %%
# Get coordinates (latitude, longtitude) for Toronto
address='Toronto, CA'
geolocator = Nominatim(user_agent="CA_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# Filter boroughs for 'Toronto' from CA postal codes
toronto_geo = df_CA_geo[df_CA_geo['Borough'].str.contains('Toronto')].reset_index(drop=True)

# %% [markdown]
# #### Create a map of Toronto with neighborhoods superimposed on top.

# %%
# Create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=12)

# Add markers to map
for df_Lat, df_Long, borough, neighborhood in zip(toronto_geo['Latitude'], toronto_geo['Longitude'], toronto_geo['Borough'], toronto_geo['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [df_Lat, df_Long],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)

# Map of Canada's postal codes for boroughs in Toronto    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Examining popular venues within the Toronto region

# %%
# Preview dataframe w/ Toronto's neighborhoods & coordinates (latitude & longitude)
toronto_geo.head(10)
# Out:
#   Postal code           Borough                                  Neighborhood  \
# 0         M5A  Downtown Toronto                    Regent Park / Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park / Ontario Provincial Government
# 2         M5B  Downtown Toronto                      Garden District, Ryerson
# 3         M5C  Downtown Toronto                                St. James Town
# 4         M4E      East Toronto                                   The Beaches
# 5         M5E  Downtown Toronto                                   Berczy Park
# 6         M5G  Downtown Toronto                            Central Bay Street
# 7         M6G  Downtown Toronto                                      Christie
# 8         M5H  Downtown Toronto                    Richmond / Adelaide / King
# 9         M6H      West Toronto                 Dufferin / Dovercourt Village
#
#     Latitude  Longitude
# 0  43.650964 -79.353041
# 1  43.661790 -79.389390
# 2  43.657491 -79.377529
# 3  43.651734 -79.375554
# 4  43.678148 -79.295349
# 5  43.645196 -79.373855
# 6  43.656072 -79.385653
# 7  43.668602 -79.420387
# 8  43.650542 -79.384116
# 9  43.664910 -79.438664

# %% [markdown]
# #### Define Foursquare Credentials, Version and Limit Parameter

# %%
CLIENT_ID = 'B3WEP1QRUXRIZQSZWGWO1JLR2P5XT1513G4K0ZLJ4AYAAZ12' # your Foursquare ID
CLIENT_SECRET = 'REIU1MYR5KK4O1033IKMEG40YOUTCEBGBJNGH3FLSZVH4PSJ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100

# %% [markdown]
# ### Gather information from fourspace using function

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    # Store into dataframe
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# #### Run the  function on each neighborhood and create a new dataframe called 'toronto_venues'.

# %%
toronto_venues = getNearbyVenues(toronto_geo['Neighborhood'],
                                   toronto_geo['Latitude'],
                                   toronto_geo['Longitude']
                                  )
# Out:
# Regent Park / Harbourfront
# Queen's Park / Ontario Provincial Government
# Garden District, Ryerson
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Richmond / Adelaide / King
# Dufferin / Dovercourt Village
# Harbourfront East / Union Station / Toronto Islands
# Little Portugal / Trinity
# The Danforth West / Riverdale
# Toronto Dominion Centre / Design Exchange
# Brockton / Parkdale Village / Exhibition Place
# India Bazaar / The Beaches West
# Commerce Court / Victoria Hotel
# Studio District
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill North & West
# High Park / The Junction South
# North Toronto West
# The Annex / North Midtown / Yorkville
# Parkdale / Roncesvalles
# Davisville
# University of Toronto / Harbord
# Runnymede / Swansea
# Moore Park / Summerhill East
# Kensington Market / Chinatown / Grange Park
# Summerhill West / Rathnelly / South Hill / Forest Hill SE / Deer Park
# CN Tower / King and Spadina / Railway Lands / Harbourfront West / Bathurst  Quay / South Niagara / Island airport
# Rosedale
# Stn A PO Boxes
# St. James Town / Cabbagetown
# First Canadian Place / Underground city
# Church and Wellesley
# Business reply mail Processing CentrE

# %%
# Shape and preview of resulting dataframe
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# (1672, 7)
#                  Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Regent Park / Harbourfront              43.650964              -79.353041
# 1  Regent Park / Harbourfront              43.650964              -79.353041
# 2  Regent Park / Harbourfront              43.650964              -79.353041
# 3  Regent Park / Harbourfront              43.650964              -79.353041
# 4  Regent Park / Harbourfront              43.650964              -79.353041
#
#                                   Venue  Venue Latitude  Venue Longitude  \
# 0                           Souk Tabule       43.653756       -79.354390
# 1  Young Centre for the Performing Arts       43.650825       -79.357593
# 2                   SOMA chocolatemaker       43.650622       -79.358127
# 3            Cluny Bistro & Boulangerie       43.650565       -79.357843
# 4                           BATLgrounds       43.647088       -79.351306
#
#              Venue Category
# 0  Mediterranean Restaurant
# 1     Performing Arts Venue
# 2            Chocolate Shop
# 3         French Restaurant
# 4        Athletics & Sports

# %%
# Store to csv file - use for saving on location lookups during code building
toronto_venues.to_csv('df_toronto_venues.csv',sep='\t',encoding='utf-8')

# %%
# Read stored csv file, drop first column and convert to dataframe
df_toronto_venues=pd.read_csv('df_toronto_venues.csv',sep='\t')
df_toronto_venues.drop('Unnamed: 0', axis=1,inplace=True)
pd.DataFrame(df_toronto_venues)
# Out:
#                                Neighborhood  Neighborhood Latitude  \
# 0                Regent Park / Harbourfront              43.650964
# 1                Regent Park / Harbourfront              43.650964
# 2                Regent Park / Harbourfront              43.650964
# 3                Regent Park / Harbourfront              43.650964
# 4                Regent Park / Harbourfront              43.650964
# ...                                     ...                    ...
# 1667  Business reply mail Processing CentrE              43.648700
# 1668  Business reply mail Processing CentrE              43.648700
# 1669  Business reply mail Processing CentrE              43.648700
# 1670  Business reply mail Processing CentrE              43.648700
# 1671  Business reply mail Processing CentrE              43.648700
#
#       Neighborhood Longitude                                 Venue  \
# 0                 -79.353041                           Souk Tabule
# 1                 -79.353041  Young Centre for the Performing Arts
# 2                 -79.353041                   SOMA chocolatemaker
# 3                 -79.353041            Cluny Bistro & Boulangerie
# 4                 -79.353041                           BATLgrounds
# ...                      ...                                   ...
# 1667              -79.385450                      Lavish & Squalor
# 1668              -79.385450                         The Gabardine
# 1669              -79.385450                          Indigospirit
# 1670              -79.385450              Ki Modern Japanese + Bar
# 1671              -79.385450                            Café Crêpe
#
#       Venue Latitude  Venue Longitude            Venue Category
# 0          43.653756       -79.354390  Mediterranean Restaurant
# 1          43.650825       -79.357593     Performing Arts Venue
# 2          43.650622       -79.358127            Chocolate Shop
# 3          43.650565       -79.357843         French Restaurant
# 4          43.647088       -79.351306        Athletics & Sports
# ...              ...              ...                       ...
# 1667       43.650304       -79.388927            Clothing Store
# 1668       43.650988       -79.381225       American Restaurant
# 1669       43.648350       -79.380347                 Bookstore
# 1670       43.647167       -79.379608       Japanese Restaurant
# 1671       43.649940       -79.390949         French Restaurant
#
# [1672 rows x 7 columns]

# %% [markdown]
# ### Analyze Venues by Neighborhood

# %%
# One hot encoding for venue category
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep=" ")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood']=toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

# Group rows by neighborhood and taking the mean of the frequency of each category
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

# %%
# Printing out each neighborhood along with the top 5 most common venues
tor_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(tor_top_venues))
    print('\n')
# Out:
# ----Berczy Park----
#                  venue  freq
# 0          Coffee Shop  0.11
# 1           Restaurant  0.05
# 2   Seafood Restaurant  0.05
# 3         Cocktail Bar  0.05
# 4               Bakery  0.03
#
#
# ----Brockton / Parkdale Village / Exhibition Place----
#                      venue  freq
# 0              Coffee Shop  0.09
# 1                     Café  0.07
# 2   Thrift / Vintage Store  0.05
# 3               Restaurant  0.05
# 4                Gift Shop  0.05
#
#
# ----Business reply mail Processing CentrE----
#                  venue  freq
# 0          Coffee Shop  0.10
# 1                Hotel  0.04
# 2                  Bar  0.04
# 3           Restaurant  0.04
# 4   Seafood Restaurant  0.03
#
#
# ----CN Tower / King and Spadina / Railway Lands / Harbourfront West / Bathurst  Quay / South Niagara / Island airport----
#                    venue  freq
# 0            Coffee Shop  0.07
# 1                   Café  0.06
# 2             Restaurant  0.06
# 3      French Restaurant  0.04
# 4   Gym / Fitness Center  0.04
#
#
# ----Central Bay Street----
#                   venue  freq
# 0           Coffee Shop  0.13
# 1        Clothing Store  0.06
# 2   Japanese Restaurant  0.04
# 3        Breakfast Spot  0.02
# 4       Bubble Tea Shop  0.02
#
#
# ----Christie----
#                  venue  freq
# 0        Grocery Store  0.23
# 1                 Café  0.23
# 2          Coffee Shop  0.15
# 3   Athletics & Sports  0.08
# 4                 Park  0.08
#
#
# ----Church and Wellesley----
#                   venue  freq
# 0           Coffee Shop  0.12
# 1   Japanese Restaurant  0.07
# 2            Restaurant  0.05
# 3               Gay Bar  0.05
# 4                  Café  0.03
#
#
# ----Commerce Court / Victoria Hotel----
#                   venue  freq
# 0           Coffee Shop  0.12
# 1            Restaurant  0.06
# 2                  Café  0.06
# 3                 Hotel  0.05
# 4   American Restaurant  0.04
#
#
# ----Davisville----
#                  venue  freq
# 0         Dessert Shop  0.11
# 1                 Café  0.07
# 2       Sandwich Place  0.07
# 3   Italian Restaurant  0.07
# 4          Pizza Place  0.07
#
#
# ----Davisville North----
#                 venue  freq
# 0                 Gym  0.17
# 1    Department Store  0.17
# 2   Convenience Store  0.17
# 3                Park  0.17
# 4      Breakfast Spot  0.17
#
#
# ----Dufferin / Dovercourt Village----
#                    venue  freq
# 0                   Park  0.17
# 1                 Bakery  0.08
# 2                    Gym  0.08
# 3   Gym / Fitness Center  0.08
# 4   Brazilian Restaurant  0.08
#
#
# ----First Canadian Place / Underground city----
#                   venue  freq
# 0           Coffee Shop  0.14
# 1                  Café  0.07
# 2            Restaurant  0.06
# 3                 Hotel  0.04
# 4   American Restaurant  0.04
#
#
# ----Forest Hill North & West----
#                          venue  freq
# 0                 Home Service   0.5
# 1                         Park   0.5
# 2            Accessories Store   0.0
# 3                 Noodle House   0.0
# 4   Modern European Restaurant   0.0
#
#
# ----Garden District, Ryerson----
#                         venue  freq
# 0                 Coffee Shop  0.10
# 1              Clothing Store  0.07
# 2   Middle Eastern Restaurant  0.04
# 3              Cosmetics Shop  0.03
# 4                        Café  0.03
#
#
# ----Harbourfront East / Union Station / Toronto Islands----
#               venue  freq
# 0        Theme Park  0.33
# 1   Harbor / Marina  0.33
# 2              Farm  0.17
# 3              Park  0.17
# 4       Music Venue  0.00
#
#
# ----High Park / The Junction South----
#                 venue  freq
# 0        Tennis Court  0.14
# 1         Gas Station  0.14
# 2       Metro Station  0.14
# 3   Convenience Store  0.14
# 4                Park  0.14
#
#
# ----India Bazaar / The Beaches West----
#              venue  freq
# 0   Sandwich Place  0.10
# 1   Ice Cream Shop  0.05
# 2              Gym  0.05
# 3      Pizza Place  0.05
# 4             Park  0.05
#
#
# ----Kensington Market / Chinatown / Grange Park----
#                     venue  freq
# 0                    Café  0.06
# 1     Dumpling Restaurant  0.05
# 2      Mexican Restaurant  0.05
# 3   Vietnamese Restaurant  0.05
# 4             Coffee Shop  0.05
#
#
# ----Lawrence Park----
#                          venue  freq
# 0                     Bus Line  0.33
# 1                  Swim School  0.33
# 2                       Lawyer  0.33
# 3                 Noodle House  0.00
# 4   Modern European Restaurant  0.00
#
#
# ----Little Portugal / Trinity----
#                venue  freq
# 0        Coffee Shop  0.08
# 1                Bar  0.08
# 2   Asian Restaurant  0.06
# 3       Cocktail Bar  0.06
# 4           Wine Bar  0.04
#
#
# ----Moore Park / Summerhill East----
#                 venue  freq
# 0          Playground  0.25
# 1         Summer Camp  0.25
# 2   Convenience Store  0.25
# 3                 Gym  0.25
# 4   Accessories Store  0.00
#
#
# ----North Toronto West----
#            venue  freq
# 0     Playground  0.25
# 1         Garden  0.25
# 2           Park  0.25
# 3       Gym Pool  0.25
# 4   Noodle House  0.00
#
#
# ----Parkdale / Roncesvalles----
#                           venue  freq
# 0                   Coffee Shop  0.09
# 1                    Restaurant  0.05
# 2              Sushi Restaurant  0.05
# 3                        Bakery  0.05
# 4   Eastern European Restaurant  0.05
#
#
# ----Queen's Park / Ontario Provincial Government----
#                  venue  freq
# 0          Coffee Shop  0.34
# 1                 Café  0.06
# 2          Yoga Studio  0.03
# 3           Hobby Shop  0.03
# 4   College Auditorium  0.03
#
#
# ----Regent Park / Harbourfront----
#                  venue  freq
# 0                  Pub  0.12
# 1                 Café  0.08
# 2          Coffee Shop  0.08
# 3          Music Venue  0.08
# 4   Athletics & Sports  0.08
#
#
# ----Richmond / Adelaide / King----
#               venue  freq
# 0       Coffee Shop  0.07
# 1              Café  0.06
# 2        Restaurant  0.06
# 3   Thai Restaurant  0.03
# 4               Gym  0.03
#
#
# ----Rosedale----
#             venue  freq
# 0   Grocery Store  0.25
# 1            Park  0.25
# 2     Candy Store  0.25
# 3      Playground  0.25
# 4       Pet Store  0.00
#
#
# ----Roselawn----
#                               venue  freq
# 0                      Home Service   0.5
# 1                               Spa   0.5
# 2                 Accessories Store   0.0
# 3           North Indian Restaurant   0.0
# 4   Molecular Gastronomy Restaurant   0.0
#
#
# ----Runnymede / Swansea----
#                  venue  freq
# 0                 Café  0.10
# 1          Coffee Shop  0.06
# 2          Pizza Place  0.06
# 3   Falafel Restaurant  0.04
# 4            Gastropub  0.04
#
#
# ----St. James Town----
#              venue  freq
# 0      Coffee Shop  0.08
# 1             Café  0.05
# 2   Cosmetics Shop  0.04
# 3       Restaurant  0.04
# 4           Bakery  0.03
#
#
# ----St. James Town / Cabbagetown----
#                  venue  freq
# 0          Coffee Shop  0.08
# 1                  Pub  0.04
# 2   Italian Restaurant  0.04
# 3          Pizza Place  0.04
# 4   Chinese Restaurant  0.04
#
#
# ----Stn A PO Boxes----
#                  venue  freq
# 0          Coffee Shop  0.10
# 1                Hotel  0.04
# 2                  Bar  0.04
# 3           Restaurant  0.04
# 4   Seafood Restaurant  0.03
#
#
# ----Studio District----
#                       venue  freq
# 0          Business Service  0.25
# 1              Night Market  0.25
# 2            Baseball Field  0.25
# 3       Government Building  0.25
# 4   North Indian Restaurant  0.00
#
#
# ----Summerhill West / Rathnelly / South Hill / Forest Hill SE / Deer Park----
#                  venue  freq
# 0   Light Rail Station  0.25
# 1          Coffee Shop  0.25
# 2          Supermarket  0.12
# 3                 Park  0.12
# 4         Skating Rink  0.12
#
#
# ----The Annex / North Midtown / Yorkville----
#                  venue  freq
# 0       Sandwich Place  0.12
# 1                 Café  0.08
# 2   Italian Restaurant  0.04
# 3         Liquor Store  0.04
# 4             Pharmacy  0.04
#
#
# ----The Beaches----
#                 venue  freq
# 0               Trail  0.17
# 1                 Pub  0.17
# 2              Church  0.17
# 3        Neighborhood  0.17
# 4   Health Food Store  0.17
#
#
# ----The Danforth West / Riverdale----
#                venue  freq
# 0           Bus Line   0.2
# 1     Discount Store   0.2
# 2   Business Service   0.2
# 3               Park   0.2
# 4      Grocery Store   0.2
#
#
# ----Toronto Dominion Centre / Design Exchange----
#                  venue  freq
# 0          Coffee Shop  0.14
# 1                Hotel  0.08
# 2                 Café  0.08
# 3           Restaurant  0.06
# 4   Seafood Restaurant  0.04
#
#
# ----University of Toronto / Harbord----
#                   venue  freq
# 0                  Café  0.15
# 1            Restaurant  0.06
# 2                  Park  0.06
# 3   Japanese Restaurant  0.06
# 4             Bookstore  0.06

# %%
# Function that sorts the venues in descending order
def return_most_common_venues(row, tor_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:tor_top_venues]

# %% [markdown]
# Put into a new dataframe and display the top 10 venues for each neighborhood

# %%
# Set number of top venues to search for
tor_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns=['Neighborhood']
for ind in np.arange(tor_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
toronto_neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
toronto_neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    toronto_neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], tor_top_venues)

toronto_neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                        Berczy Park           Coffee Shop
# 1     Brockton / Parkdale Village / Exhibition Place           Coffee Shop
# 2              Business reply mail Processing CentrE           Coffee Shop
# 3  CN Tower / King and Spadina / Railway Lands / ...           Coffee Shop
# 4                                 Central Bay Street           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0          Cocktail Bar            Restaurant    Seafood Restaurant
# 1                  Café             Gift Shop            Restaurant
# 2                   Bar            Restaurant                 Hotel
# 3                  Café            Restaurant                  Park
# 4        Clothing Store   Japanese Restaurant       Thai Restaurant
#
#      5th Most Common Venue 6th Most Common Venue     7th Most Common Venue  \
# 0                   Bakery                Lounge               Cheese Shop
# 1   Thrift / Vintage Store     Accessories Store   North Indian Restaurant
# 2      American Restaurant    Seafood Restaurant                       Pub
# 3     Gym / Fitness Center     French Restaurant                    Lounge
# 4                      Spa             Bookstore           Bubble Tea Shop
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0         Farmers Market        Breakfast Spot               Beer Bar
# 1   Caribbean Restaurant        Sandwich Place           Chiropractor
# 2                   Café    Italian Restaurant               Tea Room
# 3                    Bar    Italian Restaurant              Speakeasy
# 4         Sandwich Place            Restaurant       Sushi Restaurant

# %% [markdown]
# ### Cluster Neighborhoods
# #### Run k-means to cluster the neighborhood into 5 clusters and analyze

# %%
# import k-means from clustering stage
from sklearn.cluster import KMeans

# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering model
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

## Create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood

# add clustering labels
toronto_neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# Using Toronto neighborhood data and storing it into a dataframe to analyze venue data from within each neighborhood
toronto_merged = toronto_geo

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(toronto_neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

# %% [markdown]
# ##### Map Resulting Clusters

# %%
# Create map with clusters
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Examine Clusters

# %% [markdown]
# Cluster 1

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 12      East Toronto               0      Business Service
# 21   Central Toronto               0          Home Service
# 23   Central Toronto               0            Playground
# 33  Downtown Toronto               0            Playground
#
#    2nd Most Common Venue  3rd Most Common Venue 4th Most Common Venue  \
# 12                  Park         Discount Store         Grocery Store
# 21                  Park   Ethiopian Restaurant            Food Truck
# 23                Garden                   Park              Gym Pool
# 33                  Park            Candy Store         Grocery Store
#
#    5th Most Common Venue  6th Most Common Venue 7th Most Common Venue  \
# 12              Bus Line                   Farm              Fountain
# 21            Food Court      Food & Drink Shop                  Food
# 23     Elementary School             Food Court     Food & Drink Shop
# 33           Yoga Studio   Ethiopian Restaurant            Food Court
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 12            Food Truck            Food Court      Food & Drink Shop
# 21           Flower Shop           Fish Market      Fish & Chips Shop
# 23                  Food           Flower Shop            Fish Market
# 33     Food & Drink Shop                  Food            Flower Shop

# %% [markdown]
# Cluster 2

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 0   Downtown Toronto               1                   Pub
# 1   Downtown Toronto               1           Coffee Shop
# 2   Downtown Toronto               1           Coffee Shop
# 3   Downtown Toronto               1           Coffee Shop
# 4       East Toronto               1           Coffee Shop
# 5   Downtown Toronto               1           Coffee Shop
# 6   Downtown Toronto               1           Coffee Shop
# 7   Downtown Toronto               1                  Café
# 8   Downtown Toronto               1           Coffee Shop
# 9       West Toronto               1                  Park
# 11      West Toronto               1           Coffee Shop
# 13  Downtown Toronto               1           Coffee Shop
# 14      West Toronto               1           Coffee Shop
# 15      East Toronto               1        Sandwich Place
# 16  Downtown Toronto               1           Coffee Shop
# 17      East Toronto               1   Government Building
# 20   Central Toronto               1                   Gym
# 22      West Toronto               1         Metro Station
# 24   Central Toronto               1        Sandwich Place
# 25      West Toronto               1           Coffee Shop
# 26   Central Toronto               1          Dessert Shop
# 27  Downtown Toronto               1                  Café
# 28      West Toronto               1                  Café
# 29   Central Toronto               1            Playground
# 30  Downtown Toronto               1                  Café
# 31   Central Toronto               1           Coffee Shop
# 32  Downtown Toronto               1           Coffee Shop
# 34  Downtown Toronto               1           Coffee Shop
# 35  Downtown Toronto               1           Coffee Shop
# 36  Downtown Toronto               1           Coffee Shop
# 37  Downtown Toronto               1           Coffee Shop
# 38      East Toronto               1           Coffee Shop
#
#            2nd Most Common Venue       3rd Most Common Venue  \
# 0                    Coffee Shop                 Music Venue
# 1                           Café                 Yoga Studio
# 2                 Clothing Store   Middle Eastern Restaurant
# 3                           Café              Cosmetics Shop
# 4                         Church           Health Food Store
# 5                   Cocktail Bar                  Restaurant
# 6                 Clothing Store         Japanese Restaurant
# 7                  Grocery Store                 Coffee Shop
# 8                     Restaurant                        Café
# 9                       Pharmacy        Gym / Fitness Center
# 11                           Bar            Asian Restaurant
# 13                         Hotel                        Café
# 14                          Café                   Gift Shop
# 15                          Park          Italian Restaurant
# 16                          Café                  Restaurant
# 17                Baseball Field                Night Market
# 20              Department Store           Convenience Store
# 22                          Park                 Gas Station
# 24                          Café              Cosmetics Shop
# 25   Eastern European Restaurant                  Restaurant
# 26                          Café              Sandwich Place
# 27           Japanese Restaurant                  Restaurant
# 28                   Pizza Place                 Coffee Shop
# 29             Convenience Store                 Summer Camp
# 30            Mexican Restaurant       Vietnamese Restaurant
# 31            Light Rail Station                        Park
# 32                          Café                  Restaurant
# 34                           Bar                  Restaurant
# 35                           Pub          Italian Restaurant
# 36                          Café                  Restaurant
# 37           Japanese Restaurant                  Restaurant
# 38                           Bar                  Restaurant
#
#                         4th Most Common Venue           5th Most Common Venue  \
# 0                                        Café              Athletics & Sports
# 1                                   Bookstore              Italian Restaurant
# 2                              Cosmetics Shop                  Sandwich Place
# 3                                  Restaurant                           Diner
# 4                                Neighborhood                           Trail
# 5                          Seafood Restaurant                          Bakery
# 6                             Thai Restaurant                             Spa
# 7                                 Candy Store              Athletics & Sports
# 8                              Clothing Store                 Thai Restaurant
# 9                      Furniture / Home Store            Brazilian Restaurant
# 11                               Cocktail Bar                        Wine Bar
# 13                                 Restaurant              Seafood Restaurant
# 14                                 Restaurant          Thrift / Vintage Store
# 15                       Fast Food Restaurant               Food & Drink Shop
# 16                                      Hotel                             Gym
# 17                           Business Service                           Diner
# 20                                       Park               Food & Drink Shop
# 22   Residential Building (Apartment / Condo)            Gym / Fitness Center
# 24                          Indian Restaurant       Middle Eastern Restaurant
# 25                            Thai Restaurant                          Bakery
# 26                                Pizza Place                     Coffee Shop
# 27                                       Park                       Bookstore
# 28                         Italian Restaurant                       Gastropub
# 29                                        Gym                     Yoga Studio
# 30                                Coffee Shop   Vegetarian / Vegan Restaurant
# 31                               Skating Rink                     Supermarket
# 32                                       Park            Gym / Fitness Center
# 34                                      Hotel             American Restaurant
# 35                         Chinese Restaurant                      Restaurant
# 36                        American Restaurant                           Hotel
# 37                                    Gay Bar                            Café
# 38                                      Hotel             American Restaurant
#
#      6th Most Common Venue        7th Most Common Venue  \
# 0                     Bank               Chocolate Shop
# 1                Juice Bar          Fried Chicken Joint
# 2                     Café                        Hotel
# 3                   Bakery          Japanese Restaurant
# 4                      Pub               Farmers Market
# 5                   Lounge                  Cheese Shop
# 6                Bookstore              Bubble Tea Shop
# 7               Baby Store                   Playground
# 8                      Gym                       Bakery
# 9            Grocery Store                         Bank
# 11   Vietnamese Restaurant                  Pizza Place
# 13               Gastropub                          Bar
# 14       Accessories Store      North Indian Restaurant
# 15           Burrito Place                   Steakhouse
# 16     American Restaurant          Japanese Restaurant
# 17          Discount Store                     Fountain
# 20          Breakfast Spot                  Yoga Studio
# 22            Tennis Court            Convenience Store
# 24       French Restaurant   Modern European Restaurant
# 25        Sushi Restaurant                         Bank
# 26      Italian Restaurant              Thai Restaurant
# 27              Beer Store              Bubble Tea Shop
# 28      Falafel Restaurant                          Pub
# 29    Ethiopian Restaurant                   Food Court
# 30     Dumpling Restaurant                  Pizza Place
# 31            Liquor Store                  Yoga Studio
# 32       French Restaurant                       Lounge
# 34      Seafood Restaurant                          Pub
# 35                  Bakery                         Café
# 36                     Bar           Seafood Restaurant
# 37                     Pub                 Burger Joint
# 38      Seafood Restaurant                          Pub
#
#          8th Most Common Venue  9th Most Common Venue 10th Most Common Venue
# 0           Seafood Restaurant      French Restaurant           Tech Startup
# 1    Middle Eastern Restaurant    Distribution Center         Discount Store
# 2                Tanning Salon                  Diner    Japanese Restaurant
# 3           Italian Restaurant           Cocktail Bar    American Restaurant
# 4           Falafel Restaurant                   Farm            Yoga Studio
# 5               Farmers Market         Breakfast Spot               Beer Bar
# 6               Sandwich Place             Restaurant       Sushi Restaurant
# 7                         Park             Food Court      Food & Drink Shop
# 8                    Bookstore       Sushi Restaurant                 Lounge
# 9                       Bakery                    Gym                   Café
# 11                  Restaurant            Men's Store    Japanese Restaurant
# 13               Deli / Bodega               Tea Room                 Bakery
# 14        Caribbean Restaurant         Sandwich Place           Chiropractor
# 15                Liquor Store       Sushi Restaurant          Movie Theater
# 16                    Beer Bar     Seafood Restaurant              Gastropub
# 17                  Food Truck             Food Court      Food & Drink Shop
# 20              Farmers Market   Fast Food Restaurant      Fish & Chips Shop
# 22                Dessert Shop   Ethiopian Restaurant      Food & Drink Shop
# 24                Liquor Store           Burger Joint             Restaurant
# 25           Food & Drink Shop          Grocery Store              Bookstore
# 26          Seafood Restaurant   Fast Food Restaurant         Farmers Market
# 27           French Restaurant     Chinese Restaurant            Yoga Studio
# 28                  Restaurant       Sushi Restaurant              Bookstore
# 29           Food & Drink Shop                   Food            Flower Shop
# 30                         Bar                 Bakery                   Park
# 31          Falafel Restaurant      Food & Drink Shop                   Food
# 32                         Bar     Italian Restaurant              Speakeasy
# 34                        Café     Italian Restaurant               Tea Room
# 35                 Pizza Place                   Park             Playground
# 36                   Gastropub                    Gym    Japanese Restaurant
# 37                       Hotel           Dance Studio       Sushi Restaurant
# 38                        Café     Italian Restaurant               Tea Room

# %% [markdown]
# Cluster 3

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 19  Central Toronto               2          Home Service
#
#    2nd Most Common Venue  3rd Most Common Venue 4th Most Common Venue  \
# 19                   Spa   Ethiopian Restaurant            Food Truck
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 19            Food Court     Food & Drink Shop                  Food
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 19           Flower Shop           Fish Market      Fish & Chips Shop

# %% [markdown]
# Cluster 4

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 10  Downtown Toronto               3       Harbor / Marina
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 10            Theme Park                  Park                  Farm
#
#    5th Most Common Venue  6th Most Common Venue 7th Most Common Venue  \
# 10           Yoga Studio   Ethiopian Restaurant            Food Truck
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 10            Food Court     Food & Drink Shop                   Food

# %% [markdown]
# Cluster 5

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 18  Central Toronto               4              Bus Line
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 18           Swim School                Lawyer           Yoga Studio
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 18              Fountain            Food Truck            Food Court
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 18     Food & Drink Shop                  Food            Flower Shop

# %% [markdown]
# # Fin
# ##### 'Fin' is 'Finish' in spanish
#
# ### Comments and feedback welcome!
